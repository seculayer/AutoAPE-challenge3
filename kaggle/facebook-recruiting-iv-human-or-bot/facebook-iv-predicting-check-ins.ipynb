# %%
import numpy as np 
import pandas as pd

# %%
import os
for dirname, _, filenames in os.walk('/home/centos/moon/ktw/facebook-recruiting-iv-human-or-bot/data'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /home/centos/moon/ktw/facebook-recruiting-iv-human-or-bot/data/bids.csv.zip
# /home/centos/moon/ktw/facebook-recruiting-iv-human-or-bot/data/sampleSubmission.csv
# /home/centos/moon/ktw/facebook-recruiting-iv-human-or-bot/data/test.csv.zip
# /home/centos/moon/ktw/facebook-recruiting-iv-human-or-bot/data/train.csv.zip

# %%
train = pd.read_csv("/home/centos/moon/ktw/facebook-recruiting-iv-human-or-bot/data/train.csv.zip")
train.head()
# Out:
#                                bidder_id  \
# 0  91a3c57b13234af24875c56fb7e2b2f4rb56a
# 1  624f258b49e77713fc34034560f93fb3hu3jo
# 2  1c5f4fc669099bfbfac515cd26997bd12ruaj
# 3  4bee9aba2abda51bf43d639013d6efe12iycd
# 4  4ab12bc61c82ddd9c2d65e60555808acqgos1
#
#                          payment_account  \
# 0  a3d2de7675556553a5f08e4c88d2c228754av
# 1  a3d2de7675556553a5f08e4c88d2c228v1sga
# 2  a3d2de7675556553a5f08e4c88d2c2280cybl
# 3  51d80e233f7b6a7dfdee484a3c120f3b2ita8
# 4  a3d2de7675556553a5f08e4c88d2c22857ddh
#
#                                  address  outcome
# 0  a3d2de7675556553a5f08e4c88d2c228vt0u4      0.0
# 1  ae87054e5a97a8f840a3991d12611fdcrfbq3      0.0
# 2  92520288b50f03907041887884ba49c0cl0pd      0.0
# 3  4cb9717c8ad7e88a9a284989dd79b98dbevyi      0.0
# 4  2a96c3ce94b3be921e0296097b88b56a7x1ji      0.0

# %%
test = pd.read_csv("/home/centos/moon/ktw/facebook-recruiting-iv-human-or-bot/data/test.csv.zip")
test.head()
# Out:
#                                bidder_id  \
# 0  49bb5a3c944b8fc337981cc7a9ccae41u31d7
# 1  a921612b85a1494456e74c09393ccb65ylp4y
# 2  6b601e72a4d264dab9ace9d7b229b47479v6i
# 3  eaf0ed0afc9689779417274b4791726cn5udi
# 4  cdecd8d02ed8c6037e38042c7745f688mx5sf
#
#                          payment_account  \
# 0  a3d2de7675556553a5f08e4c88d2c228htx90
# 1  a3d2de7675556553a5f08e4c88d2c228rs17i
# 2  925381cce086b8cc9594eee1c77edf665zjpl
# 3  a3d2de7675556553a5f08e4c88d2c228nclv5
# 4  a3d2de7675556553a5f08e4c88d2c228dtdkd
#
#                                  address
# 0  5d9fa1b71f992e7c7a106ce4b07a0a754le7c
# 1  a3d2de7675556553a5f08e4c88d2c228klidn
# 2  a3d2de7675556553a5f08e4c88d2c228aght0
# 3  b5714de1fd69d4a0d2e39d59e53fe9e15vwat
# 4  c3b363a3c3b838d58c85acf0fc9964cb4pnfa

# %%
bids = pd.read_csv("/home/centos/moon/ktw/facebook-recruiting-iv-human-or-bot/data/bids.csv.zip")

# %%
bids.head(50)
# Out:
#     bid_id                              bidder_id auction       merchandise  \
# 0        0  8dac2b259fd1c6d1120e519fb1ac14fbqvax8   ewmzr           jewelry
# 1        1  668d393e858e8126275433046bbd35c6tywop   aeqok         furniture
# 2        2  aa5f360084278b35d746fa6af3a7a1a5ra3xe   wa00e        home goods
# 3        3  3939ac3ef7d472a59a9c5f893dd3e39fh9ofi   jefix           jewelry
# 4        4  8393c48eaf4b8fa96886edc7cf27b372dsibi   jefix           jewelry
# 5        5  e8291466de91b0eb4e1515143c7f74dexy2yr   3vi4t            mobile
# 6        6  eef4c687daf977f64fc1d08675c44444raj3s   kjlzx            mobile
# 7        7  ab056855c9ca9d36390feae1fa485883issyg   f5f6k        home goods
# 8        8  d600dc03b11e7d782e1e4dae091b084a1h5ch   h7jjx        home goods
# 9        9  a58ace8b671a7531c88814bc86b2a34cf0crb   3zpkj    sporting goods
# 10      10  a58ace8b671a7531c88814bc86b2a34cf0crb   z6j8b    sporting goods
# 11      11  fe37b8b29d26021ea9462bcc7c5bf5c2pbya7   jefix           jewelry
# 12      12  990db0dcdb665fb8fda5845b3e5d63082mbqq   jefix        home goods
# 13      13  7e34a26c4c339e875997f4b9239d2b5fscng4   nbx39            mobile
# 14      14  8dac2b259fd1c6d1120e519fb1ac14fbqvax8   wberf           jewelry
# 47  phone44  9759243421052631      in     94.210.47.16  4efsnqzirqtxasm
# 48  phone45  9759243421052631      in   225.146.227.95  vasstdc27m7nks3
# 49  phone46  9759243421052631      tr   172.79.230.196  ukrevxthnrqxufn

# %%
bids.sort_values(by='bidder_id' ,ascending = True)
# Out:
#           bid_id                              bidder_id auction merchandise  \
# 7179832  7179832  001068c415025a009fee375a12cff4fcnht8y   4ifac     jewelry
# 1281311  1281311  002d229ffb247009810828f648afc2ef593rb   2tdw2      mobile
# 1281292  1281292  002d229ffb247009810828f648afc2ef593rb   2tdw2      mobile
# 6805028  6805028  0030a2dd87ad2733e0873062e4f83954mkj86   obbny      mobile
# 6166636  6166636  003180b29c6a5f8f1d84a6b7b6f7be57tjj1o   cqsh6      mobile
# ...          ...                                    ...     ...         ...
# 2147278  2147278  ffd62646d600b759a985d45918bd6f0431vmz   nnciv      mobile
# 627729    627729  ffd62646d600b759a985d45918bd6f0431vmz   e26p7      mobile
# 1577704  1577704  ffd62646d600b759a985d45918bd6f0431vmz   1m1qq      mobile
# 1470059  1470059  ffd62646d600b759a985d45918bd6f0431vmz   jpxg4      mobile
# 6989098  6989098  fff2c070d8200e0a09150bd81452ce29ngcnv   2zggz  home goods
#
#            device              time country               ip              url
# 7179832  phone561  9706345052631578      bn  139.226.147.115  vasstdc27m7nks3
# 1281311  phone219  9766744210526315      sg    37.40.254.131  vasstdc27m7nks3
# 1281292  phone640  9766744105263157      sg    37.40.254.131  vasstdc27m7nks3
# 6805028  phone313  9704553947368421      ir     21.67.17.162  vnw40k8zzokijsv
# 6166636  phone102  9700605052631578      id     190.88.89.83  sj4jidex850loas
# ...           ...               ...     ...              ...              ...
# 2147278  phone195  9771693000000000      id   93.227.210.179  vasstdc27m7nks3
# 627729   phone142  9762918052631578      id      7.199.77.86  vasstdc27m7nks3
# 1577704    phone4  9768442526315789      id    3.210.112.183  vasstdc27m7nks3
# 1470059    phone4  9767929105263157      id  245.229.191.152  vasstdc27m7nks3
# 6989098  phone212  9705193473684210      th  211.163.219.144  vasstdc27m7nks3
#
# [7656334 rows x 9 columns]

# %%
bids["bidder_id"].value_counts()
# Out:
# f5b2bbad20d1d7ded3ed960393bec0f40u6hn    515033
# 197e90906939267ace2422e78e8e83889znqp    236413
# a58ace8b671a7531c88814bc86b2a34cf0crb    192565
# 13b022681839a351f07d017c0edd9ed6ao2w5    168995
# 9655ccc7c0c193f1549475f02c54dce45kjw7    161935
#                                           ...
# 7f099ea351bc35b2d1b365732c859688qq3th         1
# 35f2af180d7711f705376a66165c4185e0gvy         1
# 3b31a6f093ca6eb5a58568ac830510banmyet         1
# 970987b919bb27f09db853fd51f144a0gg5kz         1
# 01f498a0992d280de63ec346692efb2blckg2         1
# Name: bidder_id, Length: 6614, dtype: int64

# %%
alldata = pd.concat([train,test])
alldata.shape
# Out:
# (6713, 4)

# %%
alldata["payment_account"] = alldata["payment_account"].apply(lambda x:x[:5])

# %%
alldata.head()
# Out:
#                                bidder_id payment_account  \
# 0  91a3c57b13234af24875c56fb7e2b2f4rb56a           a3d2d
# 1  624f258b49e77713fc34034560f93fb3hu3jo           a3d2d
# 2  1c5f4fc669099bfbfac515cd26997bd12ruaj           a3d2d
# 3  4bee9aba2abda51bf43d639013d6efe12iycd           51d80
# 4  4ab12bc61c82ddd9c2d65e60555808acqgos1           a3d2d
#
#                                  address  outcome
# 0  a3d2de7675556553a5f08e4c88d2c228vt0u4      0.0
# 1  ae87054e5a97a8f840a3991d12611fdcrfbq3      0.0
# 2  92520288b50f03907041887884ba49c0cl0pd      0.0
# 3  4cb9717c8ad7e88a9a284989dd79b98dbevyi      0.0
# 4  2a96c3ce94b3be921e0296097b88b56a7x1ji      0.0

# %%
alldata["payment_account"].value_counts()
# Out:
# a3d2d    3520
# c9ef8      39
# 3e907      39
# dab1a      17
# a0dc9      16
#          ...
# 31e53       1
# 47f9f       1
# 74f0b       1
# 13b4d       1
# 9e0ad       1
# Name: payment_account, Length: 2526, dtype: int64

# %%
alldata["address"].sort_values().head(30)
# Out:
# 663     000475f9223b613ae0f0939fb7e580ebxi9hj
# 716     00076f1815a071703e41543535fe517d0xo8j
# 681     000925c62cb011646f322fff6cef3a3dthrsn
# 1398    001a34c28ed6d83a21edf95680766a53snmr6
# 1869    002ac5e6f2a09c6cb8588bc7875c83dbbl1wo
# 4604    002f4e7d9412d4ff6d03b45d04eadd56uelhc
# 2757    00418d691cc97c1b4c52e57fb6a0cd17f6x4a
# 579     0044c380eaf68e93bad05d11757fa56a6r91u
# 927     0044c380eaf68e93bad05d11757fa56a9or7s
# 1623    004ea345038ec0fe71240e0a6b440b1dzsg5f
# 2536    00723688292fb42aa61fcddf5eb672e1xsxog
# 161     008562f62d08804597ca6833efaf052begv9s
# 1609    00953cb044428703bd63ca04aa1ad5f3cwl4z
# 181     00953cb044428703bd63ca04aa1ad5f3m174z
# 2184    009ef047429ce31dbf4f10de9abfb233h0soc
# 1522    00ba7bea2c1bd7a3dcf49df6cb6418b1lmumr
# 3070    00de21ff3627811075faf2a3a08800534hk23
# 3227    00de21ff3627811075faf2a3a0880053jea6k
# 14      00de21ff3627811075faf2a3a0880053yi40s
# 1813    00fbee2e7b516ea80cd819debcb5b0c9rpj1a
# 3284    0103d94f73a4bbf14af298ec49b57a957k416
# 3907    010584d5d45931ef229d6f87bbed765ba0r7x
# 1388    011452b59e47a53fa1818c5d0765dea5pv3f9
# 1394    01189c5cf2cd2a242ffaa812909fb2c9i3f1z
# 227     014c8903c0a7cf8ffdb468f1847b89feix5k9
# 1591    015301c0d02938e587216e63cdec4e165cto2
# 1087    0157f1e009ae2fc517251784bc0c4f0f8mn2d
# 2146    015d2ead40dc0edd290ee6e09c43bab2omxal
# 858     016983ea67aca1b235a692a94555a3b33aywo
# 3964    017c7ddd7d967b572240e3b8b9dad66e5f9id
# Name: address, dtype: object

# %%
alldata["address"] = alldata["address"].apply(lambda x:x[:5])

# %%
alldata.head()
# Out:
#                                bidder_id payment_account address  outcome
# 0  91a3c57b13234af24875c56fb7e2b2f4rb56a           a3d2d   a3d2d      0.0
# 1  624f258b49e77713fc34034560f93fb3hu3jo           a3d2d   ae870      0.0
# 2  1c5f4fc669099bfbfac515cd26997bd12ruaj           a3d2d   92520      0.0
# 3  4bee9aba2abda51bf43d639013d6efe12iycd           51d80   4cb97      0.0
# 4  4ab12bc61c82ddd9c2d65e60555808acqgos1           a3d2d   2a96c      0.0

# %%
alldata["address"].value_counts()
# Out:
# a3d2d    1230
# 794ab      86
# 2a96c      83
# 3a7e6      29
# 23675      29
#          ...
# aaedb       1
# dc168       1
# 1d3c2       1
# 30ddc       1
# 9c353       1
# Name: address, Length: 4183, dtype: int64

# %%
x = bids.groupby("bidder_id")["bid_id"].count().reset_index()  # bidder_id를 기준으로 bid_id가 몇번 나왔는지 카운트
x
# Out:
#                                   bidder_id  bid_id
# 0     001068c415025a009fee375a12cff4fcnht8y       1
# 1     002d229ffb247009810828f648afc2ef593rb       2
# 2     0030a2dd87ad2733e0873062e4f83954mkj86       1
# 3     003180b29c6a5f8f1d84a6b7b6f7be57tjj1o       3
# 4     00486a11dff552c4bd7696265724ff81yeo9v      20
# ...                                     ...     ...
# 6609  ffbc0fdfbf19a8a9116b68714138f2902cc13   25075
# 6610  ffc4e2dd2cc08249f299cab46ecbfacfobmr3      22
# 6611  ffd29eb307a4c54610dd2d3d212bf3bagmmpl       1
# 6612  ffd62646d600b759a985d45918bd6f0431vmz     664
# 6613  fff2c070d8200e0a09150bd81452ce29ngcnv       1
#
# [6614 rows x 2 columns]

# %%
alldata = alldata.merge(x,on = "bidder_id",how = "left")

# %%
alldata
# Out:
#                                   bidder_id payment_account address  outcome  \
# 0     91a3c57b13234af24875c56fb7e2b2f4rb56a           a3d2d   a3d2d      0.0
# 1     624f258b49e77713fc34034560f93fb3hu3jo           a3d2d   ae870      0.0
# 2     1c5f4fc669099bfbfac515cd26997bd12ruaj           a3d2d   92520      0.0
# 3     4bee9aba2abda51bf43d639013d6efe12iycd           51d80   4cb97      0.0
# 4     4ab12bc61c82ddd9c2d65e60555808acqgos1           a3d2d   2a96c      0.0
# ...                                     ...             ...     ...      ...
# 6708  bef56983ba78b2ee064443ae95972877jfkyd           0f235   a98a4      NaN
# 6709  4da45cc915c32d4368ac7e773d92d4affwqrr           9e0ad   e23d9      NaN
# 6710  0d0e6220bf59ab9a0c5b5987fb2c34a9p33f9           7df4e   b6504      NaN
# 6711  4981c32c54dde65b79dbc48fd9ab6457caqze           a3d2d   9c353      NaN
# 6712  7ade70030d559a6c255be2f6feca17acnrqs0           a3d2d   a3d2d      NaN
#
#       bid_id
# 0       24.0
# 1        3.0
# 2        4.0
# 3        1.0
# 4      155.0
# ...      ...
# 6708   983.0
# 6709    66.0
# 6710  2162.0
# 6711     5.0
# 6712   382.0
#
# [6713 rows x 5 columns]

# %%
alldata["bid_id"] = alldata["bid_id"].fillna(0)
alldata
# Out:
#                                   bidder_id payment_account address  outcome  \
# 0     91a3c57b13234af24875c56fb7e2b2f4rb56a           a3d2d   a3d2d      0.0
# 1     624f258b49e77713fc34034560f93fb3hu3jo           a3d2d   ae870      0.0
# 2     1c5f4fc669099bfbfac515cd26997bd12ruaj           a3d2d   92520      0.0
# 3     4bee9aba2abda51bf43d639013d6efe12iycd           51d80   4cb97      0.0
# 4     4ab12bc61c82ddd9c2d65e60555808acqgos1           a3d2d   2a96c      0.0
# ...                                     ...             ...     ...      ...
# 6708  bef56983ba78b2ee064443ae95972877jfkyd           0f235   a98a4      NaN
# 6709  4da45cc915c32d4368ac7e773d92d4affwqrr           9e0ad   e23d9      NaN
# 6710  0d0e6220bf59ab9a0c5b5987fb2c34a9p33f9           7df4e   b6504      NaN
# 6711  4981c32c54dde65b79dbc48fd9ab6457caqze           a3d2d   9c353      NaN
# 6712  7ade70030d559a6c255be2f6feca17acnrqs0           a3d2d   a3d2d      NaN
#
#       bid_id
# 0       24.0
# 1        3.0
# 2        4.0
# 3        1.0
# 4      155.0
# ...      ...
# 6708   983.0
# 6709    66.0
# 6710  2162.0
# 6711     5.0
# 6712   382.0
#
# [6713 rows x 5 columns]

# %%
alldata.isna().sum()
# Out:
# bidder_id             0
# payment_account       0
# address               0
# outcome            4700
# bid_id                0
# dtype: int64

# %%
alldata3 = alldata[alldata["bid_id"]<20000]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize = (20,12))
sns.boxplot(alldata3["outcome"],alldata3["bid_id"])
# Out:
# /home/centos/anaconda3/envs/test_env/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='outcome', ylabel='bid_id'>

# %%
n_unique = bids.groupby("bidder_id")["auction","device","country"].nunique().reset_index()
# Out:
# /home/centos/anaconda3/envs/test_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
alldata = alldata.merge(n_unique,on = "bidder_id",how = "left")
alldata.head()
# Out:
#                                bidder_id payment_account address  outcome  \
# 0  91a3c57b13234af24875c56fb7e2b2f4rb56a           a3d2d   a3d2d      0.0
# 1  624f258b49e77713fc34034560f93fb3hu3jo           a3d2d   ae870      0.0
# 2  1c5f4fc669099bfbfac515cd26997bd12ruaj           a3d2d   92520      0.0
# 3  4bee9aba2abda51bf43d639013d6efe12iycd           51d80   4cb97      0.0
# 4  4ab12bc61c82ddd9c2d65e60555808acqgos1           a3d2d   2a96c      0.0
#
#    bid_id  auction  device  country
# 0    24.0     18.0    14.0      6.0
# 1     3.0      1.0     2.0      1.0
# 2     4.0      4.0     2.0      1.0
# 3     1.0      1.0     1.0      1.0
# 4   155.0     23.0    53.0      2.0

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
alldata["payment_account"] = le.fit_transform(alldata["payment_account"])

# %%
alldata.head()
# Out:
#                                bidder_id  payment_account address  outcome  \
# 0  91a3c57b13234af24875c56fb7e2b2f4rb56a             1628   a3d2d      0.0
# 1  624f258b49e77713fc34034560f93fb3hu3jo             1628   ae870      0.0
# 2  1c5f4fc669099bfbfac515cd26997bd12ruaj             1628   92520      0.0
# 3  4bee9aba2abda51bf43d639013d6efe12iycd              798   4cb97      0.0
# 4  4ab12bc61c82ddd9c2d65e60555808acqgos1             1628   2a96c      0.0
#
#    bid_id  auction  device  country
# 0    24.0     18.0    14.0      6.0
# 1     3.0      1.0     2.0      1.0
# 2     4.0      4.0     2.0      1.0
# 3     1.0      1.0     1.0      1.0
# 4   155.0     23.0    53.0      2.0

# %%
alldata["address"] = le.fit_transform(alldata["address"])

# %%
alldata.head()
# Out:
#                                bidder_id  payment_account  address  outcome  \
# 0  91a3c57b13234af24875c56fb7e2b2f4rb56a             1628     2652      0.0
# 1  624f258b49e77713fc34034560f93fb3hu3jo             1628     2832      0.0
# 2  1c5f4fc669099bfbfac515cd26997bd12ruaj             1628     2375      0.0
# 3  4bee9aba2abda51bf43d639013d6efe12iycd              798     1198      0.0
# 4  4ab12bc61c82ddd9c2d65e60555808acqgos1             1628      648      0.0
#
#    bid_id  auction  device  country
# 0    24.0     18.0    14.0      6.0
# 1     3.0      1.0     2.0      1.0
# 2     4.0      4.0     2.0      1.0
# 3     1.0      1.0     1.0      1.0
# 4   155.0     23.0    53.0      2.0

# %%
from datetime import datetime
bids["datetime"] = bids["time"].apply(lambda x: datetime.fromtimestamp(x/7000000))

# %%
bids["year"] = bids["datetime"].dt.year
bids["month"] = bids["datetime"].dt.month
bids["day"] = bids["datetime"].dt.day

# %%
year_mean = bids.groupby("bidder_id")["year"].mean().reset_index()
month_mean = bids.groupby("bidder_id")["month"].mean().reset_index()
day = bids.groupby("bidder_id")["day"].mean().reset_index()

# %%
alldata = alldata.merge(year_mean, on = "bidder_id", how = "left")
alldata = alldata.merge(month_mean, on = "bidder_id", how = "left")
alldata = alldata.merge(day, on = "bidder_id", how = "left")
alldata.head()
# Out:
#                                bidder_id  payment_account  address  outcome  \
# 0  91a3c57b13234af24875c56fb7e2b2f4rb56a             1628     2652      0.0
# 1  624f258b49e77713fc34034560f93fb3hu3jo             1628     2832      0.0
# 2  1c5f4fc669099bfbfac515cd26997bd12ruaj             1628     2375      0.0
# 3  4bee9aba2abda51bf43d639013d6efe12iycd              798     1198      0.0
# 4  4ab12bc61c82ddd9c2d65e60555808acqgos1             1628      648      0.0
#
#    bid_id  auction  device  country    year  month        day
# 0    24.0     18.0    14.0      6.0  2014.0    3.0  18.500000
# 1     3.0      1.0     2.0      1.0  2014.0    3.0  19.666667
# 2     4.0      4.0     2.0      1.0  2014.0    3.0  24.000000
# 3     1.0      1.0     1.0      1.0  2013.0   12.0  10.000000
# 4   155.0     23.0    53.0      2.0  2014.0    3.0  11.974194

# %%
time_diff = bids.groupby("bidder_id")["time"].apply(lambda x : x.max() - x.min()).reset_index()
alldata = alldata.merge(time_diff, on = "bidder_id",how = "left")
alldata.head()
# Out:
#                                bidder_id  payment_account  address  outcome  \
# 0  91a3c57b13234af24875c56fb7e2b2f4rb56a             1628     2652      0.0
# 1  624f258b49e77713fc34034560f93fb3hu3jo             1628     2832      0.0
# 2  1c5f4fc669099bfbfac515cd26997bd12ruaj             1628     2375      0.0
# 3  4bee9aba2abda51bf43d639013d6efe12iycd              798     1198      0.0
# 4  4ab12bc61c82ddd9c2d65e60555808acqgos1             1628      648      0.0
#
#    bid_id  auction  device  country    year  month        day          time
# 0    24.0     18.0    14.0      6.0  2014.0    3.0  18.500000  1.313558e+13
# 1     3.0      1.0     2.0      1.0  2014.0    3.0  19.666667  6.467158e+12
# 2     4.0      4.0     2.0      1.0  2014.0    3.0  24.000000  7.137000e+12
# 3     1.0      1.0     1.0      1.0  2013.0   12.0  10.000000  0.000000e+00
# 4   155.0     23.0    53.0      2.0  2014.0    3.0  11.974194  1.197795e+13

# %%
alldata["time"] = alldata["time"]/alldata["bid_id"]

# %%
alldata2 = alldata.drop(["bidder_id","outcome"],axis = 1)

# %%
alldata2.head()
# Out:
#    payment_account  address  bid_id  auction  device  country    year  month  \
# 0             1628     2652    24.0     18.0    14.0      6.0  2014.0    3.0
# 1             1628     2832     3.0      1.0     2.0      1.0  2014.0    3.0
# 2             1628     2375     4.0      4.0     2.0      1.0  2014.0    3.0
# 3              798     1198     1.0      1.0     1.0      1.0  2013.0   12.0
# 4             1628      648   155.0     23.0    53.0      2.0  2014.0    3.0
#
#          day          time
# 0  18.500000  5.473158e+11
# 1  19.666667  2.155719e+12
# 2  24.000000  1.784250e+12
# 3  10.000000  0.000000e+00
# 4  11.974194  7.727708e+10

# %%
alldata2 = alldata2.fillna(-1)

# %%
train2 = alldata2[:len(train)]
train2.shape
# Out:
# (2013, 10)

# %%
test2 = alldata2[len(train):]
test2.shape
# Out:
# (4700, 10)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 170, max_depth = 7)      # n_estimators : 트리의 갯수 지정
rf.fit(train2,train["outcome"])                       # train2 데이터에서 count열을 기준으로 모델 학습  
result = rf.predict_proba(test2)

# %%
result = result[:,1]

# %%
train["outcome"].value_counts()
# Out:
# 0.0    1910
# 1.0     103
# Name: outcome, dtype: int64

# %%
sub = pd.read_csv("/home/centos/moon/ktw/facebook-recruiting-iv-human-or-bot/data/sampleSubmission.csv")
sub.head()
# Out:
#                                bidder_id  prediction
# 0  49bb5a3c944b8fc337981cc7a9ccae41u31d7         0.0
# 1  a921612b85a1494456e74c09393ccb65ylp4y         0.0
# 2  6b601e72a4d264dab9ace9d7b229b47479v6i         0.0
# 3  eaf0ed0afc9689779417274b4791726cn5udi         0.0
# 4  cdecd8d02ed8c6037e38042c7745f688mx5sf         0.0

# %%
sub["prediction"] = result
sub.to_csv("/home/centos/moon/ktw/facebook-recruiting-iv-human-or-bot/data/sub.csv",index = False)
