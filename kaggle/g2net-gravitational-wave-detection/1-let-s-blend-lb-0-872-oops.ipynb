# %%
import os
import warnings
import pandas as pd
import numpy as np
import plotly.figure_factory as ff
import plotly.express as px
warnings.filterwarnings("ignore")

# %% [markdown]
# # Group data together
# Solutions for blend
# * 0.864 - [🕳️G2Net🕳️ - EDA and Modeling](https://www.kaggle.com/ihelon/g2net-eda-and-modeling)
# * 0.860 - [G2Net / efficientnet_b7 / baseline [inference]](https://www.kaggle.com/yasufuminakama/g2net-efficientnet-b7-baseline-inference)
# * 0.855 - [TF G2Net EDA and Starter](https://www.kaggle.com/mrigendraagrawal/tf-g2net-eda-and-starter)
# * 0.834 - [G2Net EfficientNetB1[TPU Evaluate]](https://www.kaggle.com/miklgr500/g2net-efficientnetb1-tpu-evaluate)
# * 0.855 - [G2Net: Fast and Almost Accurate Detector](https://www.kaggle.com/kneroma/g2net-fast-and-almost-accurate-detector)
# * 0.865 - [CQT G2Net EfficientNetB1[TPU Inference] ](https://www.kaggle.com/miklgr500/cqt-g2net-efficientnetb1-tpu-inference)

# %%
sub1 = pd.read_csv('../input/g2net-eda-and-modeling/model_submission.csv').sort_values('id') 
sub2 = pd.read_csv('../input/k/yasufuminakama/g2net-efficientnet-b0-baseline-inference/submission.csv').sort_values('id') 
sub3 = pd.read_csv('../input/tf-g2net-eda-and-starter/submission.csv').sort_values('id') 
sub4 = pd.read_csv('../input/g2net-efficientnetb1-tpu-evaluate/submission.csv').sort_values('id') 
sub5 = pd.read_csv('../input/g2net-fast-and-almost-accurate-detector/submission.csv').sort_values('id') 
sub6 = pd.read_csv('../input/cqt-g2net-efficientnetb1-tpu-inference/submission.csv').sort_values('id')

# %%
# Group data together
hist_data = [sub1.target, sub2.target, sub3.target, sub4.target, sub5.target, sub6.target]

group_labels = ['Yaroslav Isaienkov - 0.864', 'Y.Nakama - 0.860', 'Mrigendra Agrawal - 0.855', 'Welf Crozzo - 0.834',
                'kkiller - 0.855', 'Welf Crozzo CQT - 0.865']

# Create distplot with custom bin_size
fig = ff.create_distplot(hist_data, group_labels, bin_size=.2, show_hist=False, show_rug=False)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="6fa70807-b74a-474e-862a-8841b920bd4a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6fa70807-b74a-474e-862a-8841b920bd4a")) {                    Plotly.newPlot(                        "6fa70807-b74a-474e-862a-8841b920bd4a",                        [{"legendgroup": "Yaroslav Isaienkov - 0.864", "marker": {"color": "rgb(31, 119, 180)"}, "mode": "lines", "name": "Yaroslav Isaienkov - 0.864", "showlegend": true, "type": "scatter", "x": [0.0987161174416542, 0.10051859460771084, 0.10232107177376747, 0.1041235489398241, 0.10592602610588074, 0.10772850327193736, 0.109530980437994, 0.11133345760405064, 0.11313593477010728, 0.11493841193616391, 0.11674088910222054, 0.11854336626827718, 0.1203458434343338, 0.12214832060039044, 0.12395079776644707, 0.1257532749325037, 0.12755575209856035, 0.12935822926461696, 0.13116070643067362, 0.13296318359673023, 0.13476566076278687, 0.1365681379288435, 0.13837061509490015, 0.14017309226095676, 0.1419755694270134, 0.14377804659307003, 0.14558052375912667, 0.1473830009251833, 0.14918547809123994, 0.15
ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8cea0d4-d6f0-4897-8426-6eebef6438ad")) {                    Plotly.newPlot(                        "e8cea0d4-d6f0-4897-8426-6eebef6438ad",                        [{"coloraxis": "coloraxis", "hovertemplate": "x: %{x}<br>y: %{y}<br>color: %{z}<extra></extra>", "name": "0", "type": "heatmap", "x": ["Yaroslav Isaienkov - 0.864", "Y.Nakama - 0.860", "Mrigendra Agrawal - 0.855", "Welf Crozzo - 0.834", "kkiller - 0.855", "Welf Crozzo CQT - 0.865"], "xaxis": "x", "y": ["Yaroslav Isaienkov - 0.864", "Y.Nakama - 0.860", "Mrigendra Agrawal - 0.855", "Welf Crozzo - 0.834", "kkiller - 0.855", "Welf Crozzo CQT - 0.865"], "yaxis": "y", "z": [[0.9999999999999998, 0.9285985881204691, 0.9121229297989875, 0.8854919019653946, 0.925216298044764, 0.9311446269593721], [0.928598588120469, 0.9999999999999998, 0.9240041412584423, 0.8714056639424549, 0.9374536531372918, 0.9221207707465344], [0.9121229297989875, 0.9240041412584422, 1.0, 0.8899074019629448, 0.9365433932759544, 0.8956052503550245], [0.8854919019653946, 0.8714056639424548, 0.8899074019629448, 1.0, 0.8941574984335104, 0.847331032351267], [0.925216298044764, 0.9374536531372918, 0.9365433932759545, 0.8941574984335103, 1.0, 0.9107523916066484], [0.9311446269593721, 0.9221207707465343, 0.8956052503550245, 0.847331032351267, 0.9107523916066484, 1.0]]}],                        {"coloraxis": {"colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram" ...

# %%
sub = sub1.copy()
sub.loc[:, 'target'] = (sub1.target * 12 + 
                        sub2.target * 8 + 
                        sub3.target * 5 + 
                        sub4.target * 1 + 
                        sub5.target * 5 + 
                        sub6.target * 13) / (12 + 8 + 5 + 1 + 5 + 13)
sub.to_csv('submission.csv', index=False)

# %%
# Group data together
hist_data = [sub1.target, sub2.target, sub3.target, sub4.target, sub5.target, sub6.target, sub.target]

group_labels = ['Yaroslav Isaienkov - 0.864', 'Y.Nakama - 0.860', 'Mrigendra Agrawal - 0.855', 'Welf Crozzo - 0.834',
                'kkiller - 0.855', 'Welf Crozzo CQT - 0.865', 'Blended']

# Create distplot with custom bin_size
fig = ff.create_distplot(hist_data, group_labels, bin_size=.2, show_hist=False, show_rug=False)
fig.show()
# Out:
# <div>                            <div id="1ad75773-8d96-4872-b6c3-c6ca9e7a601b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ad75773-8d96-4872-b6c3-c6ca9e7a601b")) {                    Plotly.newPlot(                        "1ad75773-8d96-4872-b6c3-c6ca9e7a601b",                        [{"legendgroup": "Yaroslav Isaienkov - 0.864", "marker": {"color": "rgb(31, 119, 180)"}, "mode": "lines", "name": "Yaroslav Isaienkov - 0.864", "showlegend": true, "type": "scatter", "x": [0.0987161174416542, 0.10051859460771084, 0.10232107177376747, 0.1041235489398241, 0.10592602610588074, 0.10772850327193736, 0.109530980437994, 0.11133345760405064, 0.11313593477010728, 0.11493841193616391, 0.11674088910222054, 0.11854336626827718, 0.1203458434343338, 0.12214832060039044, 0.12395079776644707, 0.1257532749325037, 0.12755575209856035, 0.12935822926461696, 0.13116070643067