# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ## 데이터 로드

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
submission = pd.read_csv('sample_submission.csv')

# %% [markdown]
# ## 데이터

# %%
train.head()
# Out:
#            일자 요일  ...     중식계    석식계
# 0  2016-02-01  월  ...  1039.0  331.0
# 1  2016-02-02  화  ...   867.0  560.0
# 2  2016-02-03  수  ...  1017.0  573.0
# 3  2016-02-04  목  ...   978.0  525.0
# 4  2016-02-05  금  ...   925.0  330.0
#
# [5 rows x 12 columns]

# %%
test.head()
# Out:
#            일자  ...                                           석식메뉴
# 0  2021-01-27  ...  흑미밥 얼큰순두부찌개 쇠고기우엉볶음 버섯햄볶음 (New)아삭이고추무절임 포기김치
# 1  2021-01-28  ...            충무김밥 우동국물 오징어무침 꽃맛살샐러드 얼갈이쌈장무침 석박지
# 2  2021-01-29  ...            흑미밥 물만둣국 카레찜닭 숯불양념꼬지어묵 꼬시래기무침 포기김치
# 3  2021-02-01  ...           흑미밥 동태탕 돈육꽈리고추장조림 당면채소무침 모자반무침 포기김치
# 4  2021-02-02  ...       흑미밥 바지락살국 쇠고기청경채볶음 두부구이*볶은김치 머위된장무침 백김치
#
# [5 rows x 10 columns]

# %%
submission.head()
# Out:
#            일자  중식계  석식계
# 0  2021-01-27    0    0
# 1  2021-01-28    0    0
# 2  2021-01-29    0    0
# 3  2021-02-01    0    0
# 4  2021-02-02    0    0

# %% [markdown]
# ## 데이터 전처리

# %%
from sklearn import preprocessing
def encoding(data, col):
  le = preprocessing.LabelEncoder()
  le.fit(data[col])
  data[col] = le.transform(data[col])
  return data[col]

# %%
train['요일'] = encoding(train, '요일')
test['요일'] = encoding(test, '요일')

# %%
def dateSplit(df):
    df['일자'] = pd.to_datetime(df['일자'], format='%Y-%m-%d')
    df['year'] = df['일자'].dt.year
    df['month'] = df['일자'].dt.month
    df['day'] = df['일자'].dt.day
    return df

train = dateSplit(train)
test = dateSplit(test)

# %%
train.head()
# Out:
#           일자  요일  본사정원수  본사휴가자수  본사출장자수  ...    석식계  year month day week
# 0 2016-02-01   3   2601      50     150  ...  331.0  2016     2   1    5
# 1 2016-02-02   4   2601      50     173  ...  560.0  2016     2   2    5
# 2 2016-02-03   2   2601      56     180  ...  573.0  2016     2   3    5
# 3 2016-02-04   1   2601     104     220  ...  525.0  2016     2   4    5
# 4 2016-02-05   0   2601     278     181  ...  330.0  2016     2   5    5
#
# [5 rows x 16 columns]

# %%
test.head()
# Out:
#           일자  요일  본사정원수  본사휴가자수  ...  year  month  day week
# 0 2021-01-27   2   2983      88  ...  2021      1   27    4
# 1 2021-01-28   1   2983     104  ...  2021      1   28    4
# 2 2021-01-29   0   2983     270  ...  2021      1   29    4
# 3 2021-02-01   3   2924     108  ...  2021      2    1    5
# 4 2021-02-02   4   2924      62  ...  2021      2    2    5
#
# [5 rows x 14 columns]

# %% [markdown]
# ## 피쳐 선택

# %%
x_train = train[['요일', '본사정원수', '본사휴가자수','본사출장자수', '본사시간외근무명령서승인건수', '현본사소속재택근무자수','year','month','day']]
y1_train = train['중식계']
y2_train = train['석식계']

x_test = test[['요일', '본사정원수','본사휴가자수', '본사출장자수', '본사시간외근무명령서승인건수', '현본사소속재택근무자수','year','month','day']]

# %% [markdown]
# ## 점심과 저녁을 식수 인원을 예측할 2개 모델 생성

# %%
model1 = RandomForestRegressor(n_jobs=-1,n_estimators=10, random_state=3)
model2 = RandomForestRegressor(n_jobs=-1,n_estimators=10, random_state=3)

# %% [markdown]
# ## 학습

# %%
model1.fit(x_train, y1_train)
model2.fit(x_train, y2_train)
# Out:
# RandomForestRegressor(n_estimators=10, n_jobs=-1, random_state=3)

# %% [markdown]
# ## 추론

# %%
pred1 = model1.predict(x_test)
pred2 = model2.predict(x_test)

# %% [markdown]
# ## 결과 제출

# %%
submission['중식계'] = pred1
submission['석식계'] = pred2

# %%
submission.to_csv('fileFood.csv', index=False)
